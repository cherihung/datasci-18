# %% [markdown]
# # Project 1 Work Trial

# %% [markdown]
# ### Let's begin by exploring the dataset

# %% [markdown]
# #### 1. create a data dictionary

# %% [markdown]
# Answer:
#
# Variable | Description | Type of Variable
# ---| ---| ---
# Profession |Title of the account owner  | categorical
# Company Size | 1- small, 2- medium, 3- large| categorical
# Location | planet of the company | categorical
# Days Since Last Delivery | integer | continuous
# Number of Deliveries | integer | continuous

# %%
# Imports
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Statistical Tests
from scipy.stats import kstest, mannwhitneyu, norm, levene
from scipy import stats

# Confidence Interval Functions
from statsmodels.stats.weightstats import zconfint
from statsmodels.stats.weightstats import ztest

# Magic!
# %matplotlib inline

# %%
df = pd.read_csv('admissions.csv');
admissions = df[pd.notnull(df)]

print admissions.head(10)
# Out:
#    admit    gre   gpa  prestige
# 0      0  380.0  3.61       3.0
# 1      1  660.0  3.67       3.0
# 2      1  800.0  4.00       1.0
# 3      1  640.0  3.19       4.0
# 4      0  520.0  2.93       4.0
# 5      1  760.0  3.00       2.0
# 6      1  560.0  2.98       1.0
# 7      0  400.0  3.08       2.0
# 8      1  540.0  3.39       3.0
# 9      0  700.0  3.92       2.0

# %%
# find the admitted students
admissions = admissions[pd.notnull(admissions.gre) & pd.notnull(admissions.gpa) & pd.notnull(admissions.prestige)]

gotin = admissions[(admissions.admit == 1)]
notin = admissions[(admissions.admit == 0)]
numOfIn = len(gotin.index)
numOfNot = len(notin.index)

print "admitted:", numOfIn
print "not admitted:", numOfNot
print "total:", len(admissions.index)

print gotin.describe()
print notin.describe()
# Out:
# admitted: 126
# not admitted: 271
# total: 397
#        admit         gre         gpa    prestige
# count  126.0  126.000000  126.000000  126.000000
# mean     1.0  618.571429    3.489206    2.150794
# std      0.0  109.257233    0.371655    0.921455
# min      1.0  300.000000    2.420000    1.000000
# 25%      1.0  540.000000    3.220000    1.000000
# 50%      1.0  620.000000    3.545000    2.000000
# 75%      1.0  680.000000    3.757500    3.000000
# max      1.0  800.000000    4.000000    4.000000
#        admit         gre         gpa    prestige
# count  271.0  271.000000  271.000000  271.000000
# mean     0.0  573.579336    3.347159    2.645756
# std      0.0  116.052798    0.376355    0.918922
# min      0.0  220.000000    2.260000    1.000000
# 25%      0.0  500.000000    3.080000    2.000000
# 50%      0.0  580.000000    3.340000    3.000000
# 75%      0.0  660.000000    3.610000    3.000000
# max      0.0  800.000000    4.000000    4.000000

# %%
#visulize prestige data
presIn = gotin.prestige
presOut = notin.prestige

admissions.prestige.plot(kind='box')

# %%
gotin.prestige.plot(kind='hist')

# %%
notin.prestige.plot(kind='hist')

# %%
#separate out the columns
gre = admissions[pd.notnull(admissions.gre)].gre #red
gpa = admissions[pd.notnull(admissions.gpa)].gpa #green
pres = admissions[pd.notnull(admissions.prestige)].prestige #blue

print gre.mode(), gre.median()
print gpa.mode(), gpa.median()
print pres.mode()

all_stats = admissions.describe()
gre_stats = all_stats['gre'] #or admissions.gre.describe()
gpa_sates = all_stats['gpa']
print all_stats['gre']
# Out:
# 0    620.0
# dtype: float64 580.0
# 0    4.0
# dtype: float64 3.395
# 0    2.0
# dtype: float64
# count    398.000000
# mean     588.040201
# std      115.628513
# min      220.000000
# 25%      520.000000
# 50%      580.000000
# 75%      660.000000
# max      800.000000
# Name: gre, dtype: float64

# %%
#find fences for gre scores
Q1 = gre_stats[4]
Q3 = gre_stats[6]

IQR = Q3-Q1

Low_Fence = Q1 - 1.5 * IQR
Hi_Fence = Q3 + 1.5 * IQR

print 'IQR', IQR
print 'Low fence:', Low_Fence
print 'High fence:', Hi_Fence

greOuts = admissions[(admissions.gre < Low_Fence) & (admissions.gre > Hi_Fence)]
print greOuts
# Out:
# IQR 140.0
# Low fence: 310.0
# High fence: 870.0
# Empty DataFrame
# Columns: [admit, gre, gpa, prestige]
# Index: []

# %%
#find correlation
adm_corr = admissions.corr()[admissions.corr() != 1]
sns.heatmap(admissions.corr(), annot=True, cmap='RdBu')

# %%
pd.DataFrame(list(zip(adm_corr.columns, adm_corr.idxmax(), adm_corr.max())), columns=['Var1', 'Var2', 'Cor'])\
  .sort_values('Cor', ascending=False)
# Out:
#        Var1 Var2       Cor
# 1       gre  gpa  0.382408
# 2       gpa  gre  0.382408
# 0     admit  gre  0.182919
# 3  prestige  gpa -0.059031

# %%
admissions.plot(x='admit', y='gre', c='gre', kind='scatter')

# %%
greIn = gotin[pd.notnull(gotin.gre)].gre #grey
print 'mean:',greIn.mean()
sns.distplot(greIn, color='grey')
# Out:
# mean: 618.897637795

# %%
print 'mean:',gre.mean()
sns.distplot(gre, color='red', rug=True)
# Out:
# mean: 588.040201005

# %%
gpaIn = gotin[pd.notnull(gotin.gpa)].gpa #grey
print 'mean:',gpaIn.mean()
sns.distplot(gpaIn, color='grey', rug=True)
# Out:
# mean: 3.48920634921

# %%
print 'mean:',gpa.mean()
sns.distplot(gpa, color='green', rug=True)
# Out:
# mean: 3.39092964824

# %%
sns.distplot(pres, color='blue')

# %%
print kstest(gre, 'norm')
print kstest(gpa, 'norm')
# Out:
# KstestResult(statistic=1.0, pvalue=0.0)
# KstestResult(statistic=0.98972718363537604, pvalue=0.0)

# %%
aboveMedByGre = admissions[(admissions.gre > greIn.median()) & (admissions.admit == 1)]
print len(aboveMedByGre.index)
print len(greIn.index)

aboveMedByGpa = admissions[(admissions.gpa > gpaIn.median()) & (admissions.admit == 1)]
print len(aboveMedByGpa.index)
print len(gpaIn.index)
# Out:
# 57
# 127
# 63
# 126

# %%
sns.distplot(aboveMedByGre.gre, color='blue')

# %%
sns.distplot(aboveMedByGpa.gpa, color='blue')
